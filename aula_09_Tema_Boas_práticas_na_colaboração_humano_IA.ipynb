# %% [markdown]
# <a href="https://colab.research.google.com/github/Mateusneves14101-pixel/engenharia_de_prompt_e_aplica-o_em_IA-/blob/main/aula_09_Tema_Boas_pr%C3%A1ticas_na_colabora%C3%A7%C3%A3o_humano_IA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Dominar IA deixou de ser opcional porque ela já está transformando carreiras, produtividade e salários no mundo todo.
#
# Segundo McKinsey, a IA pode adicionar trilhões de dólares à economia global, enquanto a PwC mostra que profissionais com habilidades em IA recebem salários maiores e têm mais competitividade. Pesquisas de MIT e Stanford indicam ganhos reais de produtividade, com tarefas sendo feitas com mais rapidez e eficiência.
#
# Na prática, isso significa que quem sabe usar IA pode:
#
# Produzir mais em menos tempo
# Automatizar tarefas repetitivas
# Melhorar decisões e desempenho
# Aumentar empregabilidade e salário
# Ter mais tempo para atividades estratégicas
#
# No Brasil, com a crescente digitalização, dominar IA pode ser um grande diferencial profissional.
#
# Resumo central: IA não é mais apenas uma vantagem — está se tornando uma habilidade essencial para crescer, manter relevância e melhorar a qualidade de vida no trabalho.
# Ferramentas como GitHub Copilot e Replit ajudam equipes de programação a criar código mais rápido, automatizar tarefas repetitivas, aprender novas linguagens e aumentar a produtividade.
#
# Benefícios:
# Mais velocidade no desenvolvimento
# Apoio no aprendizado
# Maior produtividade
# Riscos:
# Dependência excessiva
# Falhas de segurança
# Problemas de licenciamento e direitos autorais
# Conclusão:
#
# A IA pode ser uma grande parceira na programação, mas não deve ser usada sem revisão. O ideal é utilizá-la como apoio, enquanto o programador continua responsável por analisar, testar e garantir segurança e qualidade.
#
# Resumo central: confiar na IA é útil até o ponto em que ela acelera o trabalho — mas a decisão final precisa continuar humana.Parecer sobre a Unidade II
#
# Na Unidade II, foi possível vivenciar na prática como a Inteligência Artificial pode atuar como suporte direto no desenvolvimento de software. Durante as atividades, foram exploradas sugestões automáticas de código, refatoração de trechos para melhoria de desempenho e organização, além da automação de tarefas repetitivas, como criação de funções básicas, correções simples e apoio na documentação.
#
# O uso de ferramentas como GitHub Copilot, Replit e Ghostwriter permitiu compreender como a IA pode otimizar o workflow de programação, tornando o processo mais rápido, produtivo e dinâmico. Essas plataformas funcionaram como assistentes técnicos, auxiliando tanto na escrita quanto na revisão de código.
#
# A prática também reforçou conteúdos fundamentais estudados na unidade, especialmente no que se refere a boas práticas de desenvolvimento, como organização, clareza, refatoração e validação constante. Ficou evidente que, embora a IA acelere processos, o conhecimento humano continua essencial para revisar resultados, garantir segurança e aplicar lógica adequada.
#
# No aspecto ético, a unidade destacou pontos importantes, como dependência excessiva, riscos de segurança, privacidade e possíveis questões de licenciamento. Isso mostrou que utilizar IA de forma responsável exige pensamento crítico e consciência profissional.
#
# Conclui-se que a Unidade II contribuiu significativamente para mostrar que ferramentas de IA não substituem o programador, mas ampliam sua capacidade produtiva. O aprendizado principal foi compreender que o melhor uso dessas tecnologias ocorre quando elas são integradas ao conhecimento técnico, à ética e às boas práticas de programação.Síntese das boas práticas na colaboração humano-IA – Parecer sobre a Unidade II
# A Unidade II reforçou que a colaboração entre ser humano e Inteligência Artificial deve ser baseada no uso estratégico, crítico e responsável da tecnologia. Durante as práticas com sugestões de código, refatoração e automação, ficou claro que ferramentas de IA podem aumentar velocidade, produtividade e aprendizado, desde que utilizadas com supervisão humana.
# Entre as principais boas práticas, destacam-se: revisar todo código gerado, validar segurança, compreender a lógica antes de aplicar soluções prontas, evitar dependência excessiva e manter atenção a questões éticas, como privacidade, licenciamento e responsabilidade técnica. A IA mostrou-se eficiente como apoio operacional, mas não substitui análise, criatividade e tomada de decisão do programador.
# O principal aprendizado da unidade foi compreender que a IA deve ser vista como parceira de desenvolvimento — uma ferramenta que potencializa capacidades humanas — e não como substituta. O papel do profissional continua essencial para interpretar contextos, corrigir falhas e garantir qualidade.
# Para a próxima unidade, voltada a Low Code/No Code, essa base será importante, pois o foco continuará na otimização de processos por meio da tecnologia, agora com plataformas que simplificam ainda mais a criação de soluções. Assim, o desafio será aplicar produtividade e inovação sem abrir mão de pensamento crítico, boas práticas e responsabilidade profissional.
